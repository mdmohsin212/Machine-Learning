# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x, y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(x, columns=['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y

# %%
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0  0.839915 -0.995879  0.462945 -1.893793  0.059308       1
# 1  0.879834 -0.782669  3.381968 -0.350644 -0.541525       0
# 2 -0.555709  1.352756  0.982852 -0.824934 -1.072545       1
# 3 -2.555396  2.411177  1.056531 -1.355813 -1.512181       1
# 4  1.021278 -2.411289  0.799242 -0.776697  0.083718       1

# %%
df.shape
# Out:
# (100, 6)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

# %%
beg = BaggingClassifier(max_features=2)

# %%
beg.fit(x_train, y_train)
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(10,8))
plot_tree(beg.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(rf.estimators_[0])
plt.show()

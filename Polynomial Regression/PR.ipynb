# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline

# %%
x = 6 * np.random.rand(200,1) - 2
y = 0.8 * x ** 2 + 0.9 + 2 + np.random.randn(200,1)

# y = 2 + 0.9X+ 0.8X^2 + noise

# %%
plt.plot(x,y,'b.')
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5791067245313235

# %%
plt.plot(x_train , lr.predict(x_train), color='red')
plt.plot(x,y,'b.')
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
poly = PolynomialFeatures(degree=2, include_bias=True)

x_tarin_trans = poly.fit_transform(x_train)
x_test_trans = poly.transform(x_test)

# %%
x_tarin_trans[0]
# Out:
# array([ 1.        , -1.67536384,  2.80684399])

# %%
lr2 = LinearRegression()
lr2.fit(x_tarin_trans, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr2.predict(x_test_trans)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.89338508552547

# %%
lr2.coef_
# Out:
# array([[0.        , 0.04901756, 0.79139171]])

# %%
lr2.intercept_
# Out:
# array([2.97867298])
